# %% [markdown]
# # Course 1 - Introduction to Python

# %% [markdown]
# ## 1. Introduction of courses

# %% [markdown]
# ## 2. Environment setup

# %% [markdown]
# Click this link -> [Environment Setup](course_0_environment_setup.pdf)

# %% [markdown]
# ## 3. Overview of Python and its applications

# %% [markdown]
# Python is a high-level, interpreted programming language known for its simplicity, readability, and versatility. It was created by Guido van Rossum and first released in 1991. Python has gained immense popularity over the years due to its beginner-friendly syntax and extensive standard library.
#
# Python finds applications in various domains, including:
# - Web development: Python offers frameworks like Django and Flask for building web applications.
# - Data analysis and scientific computing: Libraries like NumPy, Pandas, and SciPy make Python a popular choice for data manipulation and numerical computations.
# - Machine learning and artificial intelligence: Python has renowned libraries like scikit-learn and Pytorch for machine learning and deep learning.
# - Automation and scripting: Python's simplicity and wide range of libraries make it ideal for automating tasks and writing utility scripts.

# %% [markdown]
# ## 4. Introduction to Jupyter Notebook and Python Interactive Console

# %% [markdown]
# Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations, and narrative text. It provides an interactive environment for data analysis, scientific computing, and exploratory programming. Jupyter Notebook supports multiple programming languages, including Python, R, Julia, and more.

# %% [markdown]
# ### How to use Jupyter Notebook

# %% [markdown]
# Jupyter Notebook has two different types of "blocks":
# - Code block
# - Word block
#
# Add either code or word blocks as you wish

# %%
print("Hi, this is a code block")
# Out:
# Hi, this is a code block

# %% [markdown]
# **This is a word block**

# %% [markdown]
# ### Jupyter Notebook Key Features

# %% [markdown]
# **Rich Text and Multimedia**: Jupyter Notebook supports Markdown and HTML, allowing you to create rich text documents with formatted text, images, and hyperlinks.

# %% [markdown]
# Image:
# ![Example](course_0_example.png)

# %% [markdown]
# Hyperlinks: [Python Official Website](https://www.python.org/)

# %% [markdown]
# **Inline Visualization**: Jupyter Notebook seamlessly integrates with popular data visualization libraries like Matplotlib. You can create stunning visualizations directly within the notebook, making it easier to understand and communicate your data insights.

# %%
# Matplotlib Example
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
fig, ax = plt.subplots()


ax.plot(x, y1, label='sin(x)')
ax.plot(x, y2, label='cos(x)')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Trigonometric Functions')
ax.legend()
plt.show()

# %% [markdown]
# **Sharing variable**: Jupyter Notebook shares variables between different code cells within the same notebook.

# %%
x = 10
y = 20

# %%
# Different code block
print(x + y)
# Out:
# 30

# %% [markdown]
# ### Python Interactive Console

# %% [markdown]
# - The **Python interactive console**, also known as the Python shell or REPL (Read-Eval-Print Loop), is a powerful tool that allows you to execute Python code interactively. It provides an immediate feedback loop, making it ideal for learning, experimenting, and testing small code snippets.
#   - Reason: Python is an **interpreted language**
# - I will explain it in detail with examples

# %% [markdown]
# ## 5. Basic syntax, comments and indentation

# %% [markdown]
# ### Comments

# %% [markdown]
# - Single-line comments: Use the # symbol followed by the comment text.
# - Multi-line comments: Use triple quotes """ or ''' to enclose the comment text.

# %%
# This is a single-line comment
print("Hello, World!")  # Inline comments are also possible

# Multi-line comments
# Multi-line comment
"""
This is a
multi-line comment
"""
print("Python is awesome!")
# Out:
# Hello, World!
# Python is awesome!

# %% [markdown]
# ### Indentation

# %% [markdown]
# In Python, **indentation** is used to define code blocks, such as functions, loops, and conditional statements. Unlike many other programming languages, Python **does not use curly braces {} or keywords** like *begin* and *end* to delimit blocks. Instead, it relies on consistent indentation.
#
# The standard indentation is four spaces, but you can use any number of spaces or tabs **as long as you are consistent within the same block**.

# %%
if 5 > 2:
    print("Five is greater than two!") # 4-space indentation is recommended

# %%
if 5 > 2:
 print("Five is greater than two!") # 1-space indentation also works
 print("Five is greater than two!") # Consist all lines with the same indentation
if 5 > 2:
        print("Five is greater than two!") # 8-space indentation also works
# Out:
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# ### Variables and Assignment

# %% [markdown]
# #### Assignment

# %% [markdown]
# In Python, you can assign values to variables using the `=` operator. Python is a **dynamically-typed language**, which means you don't need to specify the type of the variable explicitly.

# %% [markdown]
# **Syntax: variable_name = value**

# %% [markdown]
# The value can be a
# - literal (e.g., a number or a string)
# - the result of an expression
# - another variable.

# %%
x = 10 # Assigning a value to x
name = "Alice" # Assigning a string to a variable
result = 2 + 3 # Assigning the result of an expression to a variable
y = x # Assigning the value of one variable to another variable

# %%
print(f"x = {x}, name = {name}, result = {result}, y = {y}")
# Out:
# x = 10, name = Alice, result = 5, y = 10

# %% [markdown]
# #### Multiple Assignment

# %% [markdown]
# Python allows you to assign multiple values to multiple variables in a single line using multiple assignment.

# %%
x, y, z = 1, 2, 3
print(f"x = {x}, y = {y}, z = {z}")
# Out:
# x = 1, y = 2, z = 3

# %% [markdown]
# You can also use multiple assignment to swap the values of two variables without using a temporary variable:

# %%
x, y = 10, 20
print(x, y)

x, y = y, x
print(x, y)
# Out:
# 10 20
# 20 10

# %% [markdown]
# #### Reassignment

# %% [markdown]
# Variables in Python can be reassigned to new values at any point in the program. The previous value of the variable is overwritten by the new value.

# %%
x = 10
print(x)

x = 20
print(x)
# Out:
# 10
# 20
# 25

# %%
"""
Note: The value of x is 20 initially. 
The statement x = x + 5 increases the value of x by 5.
So, the value of x becomes 25 after this statement.
"""
x = x + 5
print(x)
